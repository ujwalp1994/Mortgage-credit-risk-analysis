# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.core.display import display, HTML

# %matplotlib inline

# %% [markdown]
# ## Loading the Data

# %%
data = pd.read_csv("2017_PUDB_Export.csv")

# %%
data.head()
# Out:
#    Year  Assigned ID     Bank  FIPSStateCode  FIPSCountyCode    MSA  \
# 0  2017      2092102  Atlanta             72              15  25020
# 1  2017      2092103  Atlanta             66              10  99999
# 2  2017      2092104  Atlanta             66              10  99999
# 3  2017      2092105  Atlanta             48             439  19100
# 4  2017      2092106  Atlanta              6              99  33700
#
#     FeatureID    Tract  MinPer  TraMedY   ...    Corace2  Corace3  Corace4  \
# 0     1609553  2802.02   99.15    15863   ...          6        6        6
# 1  9999999999  9540.00   92.90    75804   ...          6        6        6
# 2     1389637  9563.00   92.90    49250   ...          6        6        6
# 3     1337443  1141.03   25.31   102791   ...          6        6        6
# 4      277574    32.02   71.74    58235   ...          6        6        6
#
#    Corace5  HOEPA  LienStatus  SpcHsgGoals  FedFinStbltyPlan  AcqTyp  GSEREO
# ...

# %%
data.describe()
# Out:
#           Year   Assigned ID  FIPSStateCode  FIPSCountyCode           MSA  \
# count  55990.0  5.599000e+04   55990.000000    55990.000000  55990.000000
# mean    2017.0  2.100277e+06      27.259832       81.132470  35921.761654
# std        0.0  1.616339e+04      13.833729       68.953152  23564.415009
# min     2017.0  2.072282e+06       1.000000        1.000000  10100.000000
# 25%     2017.0  2.086280e+06      18.000000       31.000000  19380.000000
# 50%     2017.0  2.100278e+06      25.000000       67.000000  30460.000000
# 75%     2017.0  2.114275e+06      39.000000      115.000000  41860.000000
# max     2017.0  2.128272e+06      72.000000      840.000000  99999.000000
#
#           FeatureID         Tract        MinPer        TraMedY        LocMedY  \
# count  5.599000e+04  55990.000000  55990.000000   55990.000000   55990.000000
# mean   4.546789e+09   2864.767451     18.440787   82372.062333   69385.696642
# ...

# %%
data.columns
# Out:
# Index(['Year', 'Assigned ID', 'Bank', 'FIPSStateCode', 'FIPSCountyCode', 'MSA',
#        'FeatureID', 'Tract', 'MinPer', 'TraMedY', 'LocMedY', 'Tractrat',
#        'Income', 'CurAreY', 'IncRat', 'UPB', 'LTV', 'MortDate', 'AcquDate',
#        'Purpose', 'Coop', 'Product', 'FedGuar', 'Term', 'AmorTerm', 'SellType',
#        'NumBor', 'First', 'CICA', 'BoRace', 'CoRace', 'BoGender', 'CoGender',
#        'BoAge', 'CoAge', 'Occup', 'NumUnits', 'Bed1', 'Bed2', 'Bed3', 'Bed4',
#        'Aff1', 'Aff2', 'Aff3', 'Aff4', 'Rent1', 'Rent2', 'Rent3', 'Rent4',
#        'RentUt1', 'RentUt2', 'RentUt3', 'RentUt4', 'Geog', 'Rate', 'Amount',
#        'Front', 'Back', 'BoCreditScor', 'CoBoCreditScor', 'PMI', 'Self',
#        'PropType', 'ArmIndex', 'ArmMarg', 'PrepayP', 'BoEth', 'Race2', 'Race3',
#        'Race4', 'Race5', 'CoEth', 'Corace2', 'Corace3', 'Corace4', 'Corace5',
#        'HOEPA', 'LienStatus', 'SpcHsgGoals', 'FedFinStbltyPlan', 'AcqTyp',
#        'GSEREO'],
#       dtype='object')

# %% [markdown]
# ### Displaying the all the columns and 100 rows
# Using display(HTML) to view all columns

# %%
data1 = data.head(100)

display(HTML(data1.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>Assigned ID</th>
#       <th>Bank</th>
#       <th>FIPSStateCode</th>
#       <th>FIPSCountyCode</th>
#       <th>MSA</th>
#       <th>FeatureID</th>
#       <th>Tract</th>
#       <th>MinPer</th>
#       <th>TraMedY</th>
#       <th>LocMedY</th>
#       <th>Tractrat</th>
#       <th>Income</th>
#       <th>CurAreY</th>
#       <th>IncRat</th>
#       <th>UPB</th>
#       <th>LTV</th>
#       <th>MortDate</th>
#       <th>AcquDate</th>
#       <th>Purpose</th>
#       <th>Coop</th>
#       <th>Product</th>
#       <th>FedGuar</th>
#       <th>Term</th>
#       <th>AmorTerm</th>
#       <th>SellType</th>
#       <th>NumBor</th>
#       <th>First</th>
#       <th>CICA</th>
#       <th>BoRace</th>
#       <th>CoRace</th>
#       <th>BoGender</th>
#       <th>CoGender</th>
#       <th>BoAge</th>
#       <th>CoAge</th>
#       <th>Occup</th>
# ...

# %%
data.shape
# Out:
# (55990, 82)

# %% [markdown]
# ## Correlations

# %%
data.columns
# Out:
# Index(['Year', 'Assigned ID', 'Bank', 'FIPSStateCode', 'FIPSCountyCode', 'MSA',
#        'FeatureID', 'Tract', 'MinPer', 'TraMedY', 'LocMedY', 'Tractrat',
#        'Income', 'CurAreY', 'IncRat', 'UPB', 'LTV', 'MortDate', 'AcquDate',
#        'Purpose', 'Coop', 'Product', 'FedGuar', 'Term', 'AmorTerm', 'SellType',
#        'NumBor', 'First', 'CICA', 'BoRace', 'CoRace', 'BoGender', 'CoGender',
#        'BoAge', 'CoAge', 'Occup', 'NumUnits', 'Bed1', 'Bed2', 'Bed3', 'Bed4',
#        'Aff1', 'Aff2', 'Aff3', 'Aff4', 'Rent1', 'Rent2', 'Rent3', 'Rent4',
#        'RentUt1', 'RentUt2', 'RentUt3', 'RentUt4', 'Geog', 'Rate', 'Amount',
#        'Front', 'Back', 'BoCreditScor', 'CoBoCreditScor', 'PMI', 'Self',
#        'PropType', 'ArmIndex', 'ArmMarg', 'PrepayP', 'BoEth', 'Race2', 'Race3',
#        'Race4', 'Race5', 'CoEth', 'Corace2', 'Corace3', 'Corace4', 'Corace5',
#        'HOEPA', 'LienStatus', 'SpcHsgGoals', 'FedFinStbltyPlan', 'AcqTyp',
#        'GSEREO'],
#       dtype='object')

# %%
corr = data.corr()

display(HTML(corr.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>Assigned ID</th>
#       <th>FIPSStateCode</th>
#       <th>FIPSCountyCode</th>
#       <th>MSA</th>
#       <th>FeatureID</th>
#       <th>Tract</th>
#       <th>MinPer</th>
#       <th>TraMedY</th>
#       <th>LocMedY</th>
#       <th>Tractrat</th>
#       <th>Income</th>
#       <th>CurAreY</th>
#       <th>IncRat</th>
#       <th>UPB</th>
#       <th>LTV</th>
#       <th>MortDate</th>
#       <th>AcquDate</th>
#       <th>Purpose</th>
#       <th>Coop</th>
#       <th>Product</th>
#       <th>FedGuar</th>
#       <th>Term</th>
#       <th>AmorTerm</th>
#       <th>SellType</th>
#       <th>NumBor</th>
#       <th>First</th>
#       <th>CICA</th>
#       <th>BoRace</th>
#       <th>CoRace</th>
#       <th>BoGender</th>
#       <th>CoGender</th>
#       <th>BoAge</th>
#       <th>CoAge</th>
#       <th>Occup</th>
#       <th>NumUnits</th>
# ...

# %% [markdown]
# ##### Lots of negative values and NaN

# %%
data.columns
# Out:
# Index(['Year', 'Assigned ID', 'Bank', 'FIPSStateCode', 'FIPSCountyCode', 'MSA',
#        'FeatureID', 'Tract', 'MinPer', 'TraMedY', 'LocMedY', 'Tractrat',
#        'Income', 'CurAreY', 'IncRat', 'UPB', 'LTV', 'MortDate', 'AcquDate',
#        'Purpose', 'Coop', 'Product', 'FedGuar', 'Term', 'AmorTerm', 'SellType',
#        'NumBor', 'First', 'CICA', 'BoRace', 'CoRace', 'BoGender', 'CoGender',
#        'BoAge', 'CoAge', 'Occup', 'NumUnits', 'Bed1', 'Bed2', 'Bed3', 'Bed4',
#        'Aff1', 'Aff2', 'Aff3', 'Aff4', 'Rent1', 'Rent2', 'Rent3', 'Rent4',
#        'RentUt1', 'RentUt2', 'RentUt3', 'RentUt4', 'Geog', 'Rate', 'Amount',
#        'Front', 'Back', 'BoCreditScor', 'CoBoCreditScor', 'PMI', 'Self',
#        'PropType', 'ArmIndex', 'ArmMarg', 'PrepayP', 'BoEth', 'Race2', 'Race3',
#        'Race4', 'Race5', 'CoEth', 'Corace2', 'Corace3', 'Corace4', 'Corace5',
#        'HOEPA', 'LienStatus', 'SpcHsgGoals', 'FedFinStbltyPlan', 'AcqTyp',
#        'GSEREO'],
#       dtype='object')

# %% [markdown]
# ##### Dropping some non nessarary correlations

# %%
data_corr = data.drop(['BoEth', 'Race2', 'Race3', 'Race4', 'Race5','CoEth', 'Corace2', 'Corace3', 'Corace4', 'Corace5','Rent1', 'Rent2', 'Rent3', 'Rent4',
       'RentUt1', 'RentUt2', 'RentUt3', 'RentUt4'], axis=1)

# %%
corr = data_corr.corr()
corr2 = corr[(corr >0.4) & (corr !=1)]
corr3 = corr2.dropna(thresh=1)

# %%
from matplotlib import pyplot
pyplot.figure(figsize=(25, 18)) # width and height in inches
sns.heatmap(corr3, cbar = True,   annot=True,  cmap= 'coolwarm')

# %% [markdown]
# ### TOO many features, to plot in a single heatmap!    😅
# Lets try to find correlations between some important features and interest rate (individually)
# <br>We will consider discrete features with respect to continous features

# %% [markdown]
# ### 1) Starting with BoAge and Rate:
# BoAge: Age of Borrower in years

# %%
sns.jointplot('Rate','BoAge',data,kind='scatter')
# Out:
# /Users/chaitanyapotnis/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# pearson correlation coefficient = -0.068 <br>
# which is almost 0 therefore there is no correlation between Borrowers Age and Rate
#
# ### 2) Lets try CoAge and Rate

# %%
sns.jointplot('Rate','CoAge',data,kind='scatter')
# Out:
# /Users/chaitanyapotnis/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# pearson correlation coefficient = -0.027 <br>
# which is almost 0 therefore there is no correlation between CoBorrowers Age and Rate

# %% [markdown]
# ### 3) Correlations between Amount and Rate

# %%
sns.jointplot('Amount','Rate',data,kind='scatter')
# Out:
# /Users/chaitanyapotnis/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### 4) Lets try Income, Amount, Rate

# %%
amount_rate_income = data[["Amount", "Rate", "Income" ]]

# %%
amount_rate_income.head()
# Out:
#    Amount    Rate  Income
# 0   75000  0.0288   60588
# 1  520000  0.0325  210264
# 2  429831  0.0325  114744
# 3  251800  0.0338  164988
# 4  290613  0.0325   56160

# %%
sns.pairplot(amount_rate_income.dropna())

# %% [markdown]
# #### No luck, no correlation between Amount, Income, Rate.
#
# ### 5) LETS DO SOME ANALYSIS ON CREDIT SCORE AND RATE

# %%
data["BoCreditScor"].describe()
# Out:
# count    55990.000000
# mean         4.353724
# std          0.852659
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          9.000000
# Name: BoCreditScor, dtype: float64

# %%
data[data["BoCreditScor"] ==1].describe()["Rate"]
# Out:
# count    130.000000
# mean       0.040912
# std        0.003439
# min        0.032500
# 25%        0.037500
# 50%        0.041300
# 75%        0.043800
# max        0.047500
# Name: Rate, dtype: float64

# %%
data[data["BoCreditScor"] ==2].describe()["Rate"]
# Out:
# count    2066.000000
# mean        0.040454
# std         0.003593
# min         0.027500
# 25%         0.037500
# 50%         0.040000
# 75%         0.042500
# max         0.051300
# Name: Rate, dtype: float64

# %%
data[data["BoCreditScor"] ==3].describe()["Rate"]
# Out:
# count    6035.000000
# mean        0.040493
# std         0.003369
# min         0.027500
# 25%         0.038800
# 50%         0.040000
# 75%         0.042500
# max         0.050000
# Name: Rate, dtype: float64

# %%
data[data["BoCreditScor"] ==4].describe()["Rate"]
# Out:
# count    17773.000000
# mean         0.039878
# std          0.002994
# min          0.026300
# 25%          0.038800
# 50%          0.040000
# 75%          0.041300
# max          0.051300
# Name: Rate, dtype: float64

# %%
data[data["BoCreditScor"] ==5].describe()["Rate"]
# Out:
# count    29892.000000
# mean         0.039161
# std          0.002899
# min          0.025000
# 25%          0.037500
# 50%          0.039900
# 75%          0.041300
# max          0.050000
# Name: Rate, dtype: float64

# %%
print("Average Interest Rate: ")
c1 = data[data["BoCreditScor"] ==1].describe()["Rate"]['mean']
c2 = data[data["BoCreditScor"] ==2].describe()["Rate"]['mean']
c3 = data[data["BoCreditScor"] ==3].describe()["Rate"]['mean']
c4 = data[data["BoCreditScor"] ==4].describe()["Rate"]['mean']
c5 = data[data["BoCreditScor"] ==5].describe()["Rate"]['mean']


print("1) CREDIT SCORE = <620 \nAverage interest rate =",c1,"\n\n2)CREDIT SCORE = 620 to < 660\nAverage interest rate =",c2," \n\n3) CREDIT SCORE = 660 < 700\nAverage interest rate = ",c3," \n\n4) CREDIT SCORE =700 < 760\nAverage interest rate = ",c4," \n\n5) CREDIT SCORE = 760\nAverage interest rate = ",c5)
# Out:
# Average Interest Rate:
# 1) CREDIT SCORE = <620
# Average interest rate = 0.040911538461538464
#
# 2)CREDIT SCORE = 620 to < 660
# Average interest rate = 0.04045406582768636
#
# 3) CREDIT SCORE = 660 < 700
# Average interest rate =  0.04049320629660314
#
# 4) CREDIT SCORE =700 < 760
# Average interest rate =  0.039878112867833646
#
# 5) CREDIT SCORE = 760
# Average interest rate =  0.039161233774924094

# %% [markdown]
# <br>
# <br>
# <br>
# Prime Interest Rates in 2017:<br>
# 12/14/2017	4.50%<br>
# 06/15/2017	4.25%<br>
# 03/16/2017	4.00%<br>
#
# *Soucre: https://www.jpmorganchase.com/corporate/About-JPMC/historical-prime-rate.htm
# <br>
# <br>
# <br>
# #### Finally, Some correlation between Credit score and Rate:
# Good the score, less the interest rate
#
# <br>
# ### Lets try location wise (Federal Home Loan Bank District)

# %%
for bank in set(data["Bank"]):
    print("Average Interest Rate in :",bank)
    print(data[data["Bank"] =="{0}".format(bank)].describe()["Rate"]['mean'],"\n")
# Out:
# Average Interest Rate in : Topeka
# 0.03935838196590042
#
# Average Interest Rate in : Boston
# 0.03916183929116966
#
# Average Interest Rate in : Pittsburgh
# 0.04161394998493644
#
# Average Interest Rate in : Chicago
# 0.039630017369335795
#
# Average Interest Rate in : San Francisco
# 0.04161605972323505
#
# Average Interest Rate in : Atlanta
# 0.036659400749063785
#
# Average Interest Rate in : Indianapolis
# 0.03942237391747393
#
# Average Interest Rate in : New York
# 0.03952871287128691
#
# Average Interest Rate in : Des Moines
# 0.03893721350187584
#
# Average Interest Rate in : Dallas
# 0.042373804971320185
#
# Average Interest Rate in : Cincinnati
# 0.03888262222222253

# %% [markdown]
# ##### We can see the Average interest differs as per the location of Federal Home Loan Bank District

# %% [markdown]
# #### Lets try Correlation Credit Score and LTV

# %%
#sns.jointplot('LTV','BoCreditScor',data,kind='scatter')
print("CREDIT SCORE")
c1 = data[data["BoCreditScor"] == 1].describe()["LTV"]['mean']
c2 = data[data["BoCreditScor"] == 2].describe()["LTV"]['mean']
c3 = data[data["BoCreditScor"] == 3].describe()["LTV"]['mean']
c4 = data[data["BoCreditScor"] == 4].describe()["LTV"]['mean']
c5 = data[data["BoCreditScor"] == 5].describe()["LTV"]['mean']


print("1 = <620 \nAverage LTV =",c1,"\n\n2 = 620 to < 660\nAverage LTV =",c2," \n\n3 = 660 < 700\nAverage LTV = ",c3," \n\n4 =700 < 760\nAverage LTV = ",c4," \n\n5 = 760\nAverage LTV = ",c5)
# Out:
# CREDIT SCORE
# 1 = <620
# Average LTV = 0.9463076923076914
#
# 2 = 620 to < 660
# Average LTV = 0.8534075508228454
#
# 3 = 660 < 700
# Average LTV =  0.8141971830986046
#
# 4 =700 < 760
# Average LTV =  0.7857367917627406
#
# 5 = 760
# Average LTV =  0.740714906998418

# %% [markdown]
# ##### Here some unexpected correlation Less Credit Score people got more LTV
# <br>
# <br>
# <br>
# #### Lets try Credit Score and AverageLoan Amount

# %%
#sns.jointplot('LTV','BoCreditScor',data,kind='scatter')
print("CREDIT SCORE")
c1 = data[data["BoCreditScor"] == 1].describe()["Amount"]['mean']
c2 = data[data["BoCreditScor"] == 2].describe()["Amount"]['mean']
c3 = data[data["BoCreditScor"] == 3].describe()["Amount"]['mean']
c4 = data[data["BoCreditScor"] == 4].describe()["Amount"]['mean']
c5 = data[data["BoCreditScor"] == 5].describe()["Amount"]['mean']

print("1 = <620 \nAverage LTV =",c1,"\n\n2 = 620 to < 660\nAverage LTV =",c2," \n\n3 = 660 < 700\nAverage LTV = ",c3," \n\n4 =700 < 760\nAverage LTV = ",c4," \n\n5 = 760\nAverage LTV = ",c5)
# Out:
# CREDIT SCORE
# 1 = <620
# Average LTV = 157471.61538461538
#
# 2 = 620 to < 660
# Average LTV = 174912.33107454018
#
# 3 = 660 < 700
# Average LTV =  203647.8097763049
#
# 4 =700 < 760
# Average LTV =  232021.93501378497
#
# 5 = 760
# Average LTV =  238662.67549846112

# %% [markdown]
# ##### Here peoplewith more Credit score got higher amount of Loan
# <br>
# <br>
# <br>
# #### Now Self and Average LTV
# <br>
# Self-Employed Indicator<br>
# 1=yes<br>
# 2=no

# %%
data[data["Self"] == 1].describe()["Rate"]['mean']
# Out:
# 0.03951643933955519

# %%
data[data["Self"] == 2].describe()["Rate"]['mean']
# Out:
# 0.039591508984891076

# %% [markdown]
# #### Term and Rate

# %%
sns.jointplot('Term','Rate',data,kind='scatter')
# Out:
# /Users/chaitanyapotnis/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# #### Trying Borrowers Gender and LTV

# %%
data[data["BoGender"] == 2].describe()["LTV"]['mean']
# Out:
# 0.7710953388384466

# %%
data[data["Self"] == 1].describe()["LTV"]['mean']
# Out:
# 0.7154522613065543

# %% [markdown]
# ## Removing the unnecessary features
#
# 9999999999=no non-owner-occupied dwelling units

# %%
print("\n\nRentUt1")
display(HTML(data[data["RentUt1"] != 9999999999].to_html()))
print("\n\nRentUt2")
display(HTML(data[data["RentUt2"] != 9999999999].to_html()))
print("\n\nRentUt3")
display(HTML(data[data["RentUt3"] != 9999999999].to_html()))
print("\n\nRentUt4")
display(HTML(data[data["RentUt4"] != 9999999999].to_html()))
print("\n\nRent1")
display(HTML(data[data["Rent1"] != 9999999999].to_html()))
print("\n\nRent2")
display(HTML(data[data["Rent2"] != 9999999999].to_html()))
print("\n\nRent3")
display(HTML(data[data["Rent3"] != 9999999999].to_html()))
print("\n\nRent4")
display(HTML(data[data["Rent4"] != 9999999999].to_html()))
# Out:
# RentUt1
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>Assigned ID</th>
#       <th>Bank</th>
#       <th>FIPSStateCode</th>
#       <th>FIPSCountyCode</th>
#       <th>MSA</th>
#       <th>FeatureID</th>
#       <th>Tract</th>
#       <th>MinPer</th>
#       <th>TraMedY</th>
#       <th>LocMedY</th>
#       <th>Tractrat</th>
#       <th>Income</th>
#       <th>CurAreY</th>
#       <th>IncRat</th>
#       <th>UPB</th>
#       <th>LTV</th>
#       <th>MortDate</th>
#       <th>AcquDate</th>
#       <th>Purpose</th>
#       <th>Coop</th>
#       <th>Product</th>
#       <th>FedGuar</th>
#       <th>Term</th>
#       <th>AmorTerm</th>
#       <th>SellType</th>
#       <th>NumBor</th>
#       <th>First</th>
#       <th>CICA</th>
#       <th>BoRace</th>
#       <th>CoRace</th>
#       <th>BoGender</th>
#       <th>CoGender</th>
#       <th>BoAge</th>
#       <th>CoAge</th>
#       <th>Occup</th>
# ...

# %% [markdown]
# #### Removing the Rent1, Rent2, Rent3, Rent4, RentUt1, RentUt2, RentUt3, RentUt4 feature as they all have the same values for every row(wont help in the analysis)
# * Just the Rent1 has one application id having differnet value(not 9999999999), still we will drop it.

# %%
del data["RentUt1"]
del data["RentUt2"]
del data["RentUt3"]
del data["RentUt4"]
del data["Rent1"]
del data["Rent2"]
del data["Rent3"]
del data["Rent4"]
